# %%
import requests

# %%
result_dict = {
    "organic_results": [
      {
        "position": 1,
        "block_position": 3,
        "title": "Wahl zum 21. Deutschen Bundestag am 23. Februar 2025",
        "link": "https://www.bundeswahlleiterin.de/bundestagswahlen/2025.html",
        "domain": "www.bundeswahlleiterin.de",
        "displayed_link": "https://www.bundeswahlleiterin.de › bundestagswahlen",
        "snippet": "Wahl zum 21. Deutschen Bundestag am 23. Februar 2025. Der Deutsche Bundestag ist die Volksvertretung der Bundesrepublik Deutschland und als maßgebliches ...",
        "prerender": False,
        "sitelinks": {
          "inline": [
            {
              "title": "Informationen für Wählende",
              "link": "https://www.bundeswahlleiterin.de/bundestagswahlen/2025/informationen-waehler.html"
            },
            {
              "title": "Termine und Fristen",
              "link": "https://www.bundeswahlleiterin.de/bundestagswahlen/2025/termine.html"
            },
            {
              "title": "Wahlkreise",
              "link": "https://www.bundeswahlleiterin.de/bundestagswahlen/2025/wahlkreiseinteilung.html"
            },
            {
              "title": "Mitteilungen",
              "link": "https://www.bundeswahlleiterin.de/bundestagswahlen/2025/mitteilungen.html"
            }
          ]
        },
        "rich_snippet": {
          "top": {
            "detected_extensions": {},
            "extensions": [
              "‎Informationen für Wählende",
              "‎Termine und Fristen",
              "‎Wahlkreise",
              "‎Mitteilungen"
            ]
          }
        }
      },
      {
        "position": 2,
        "block_position": 4,
        "title": "Bundestagswahl 2025",
        "link": "https://www.bundestag.de/wahl",
        "domain": "www.bundestag.de",
        "displayed_link": "https://www.bundestag.de › wahl",
        "snippet": "Wahl zum 21. Deutschen Bundestag am 23. Februar 2025 ... Wähler stehen Schlange in einem Wahlraum. ... Die Wahlen zum Bundestag sind allgemein, unmittelbar, frei, ...",
        "prerender": False,
        "rich_snippet": {
          "top": {
            "detected_extensions": {},
            "extensions": [
              "‎Wahl zum 21. Deutschen...",
              "‎Vorgezogene Neuwahl mit..."
            ]
          }
        }
      },
      {
        "position": 3,
        "block_position": 6,
        "title": "Bundestagswahl 2025",
        "link": "https://de.wikipedia.org/wiki/Bundestagswahl_2025",
        "domain": "de.wikipedia.org",
        "displayed_link": "https://de.wikipedia.org › wiki › Bundestagswahl_2025",
        "snippet": "Die Wahl zum 21. Deutschen Bundestag wird als vorgezogene Neuwahl am 23. Februar 2025 stattfinden. Voraussetzung für diesen Termin war die gescheiterte ...",
        "prerender": False,
        "sitelinks": {
          "inline": [
            {
              "title": "Umfragen und Prognosen",
              "link": "https://de.wikipedia.org/wiki/Bundestagswahl_2025/Umfragen_und_Prognosen"
            },
            {
              "title": "Bündnis Sahra Wagenknecht",
              "link": "https://de.wikipedia.org/wiki/B%C3%BCndnis_Sahra_Wagenknecht"
            },
            {
              "title": "Bruch der Ampelkoalition",
              "link": "https://de.wikipedia.org/wiki/Bruch_der_Ampelkoalition_in_Deutschland_2024"
            }
          ]
        },
        "rich_snippet": {
          "top": {
            "detected_extensions": {},
            "extensions": [
              "‎Umfragen und Prognosen",
              "‎Bündnis Sahra Wagenknecht",
              "‎Bruch der Ampelkoalition"
            ]
          }
        }
      },
      {
        "position": 4,
        "block_position": 7,
        "title": "Wahl zum 21. Deutschen Bundestag am 23. Februar 2025",
        "link": "https://www.bundestag.de/parlament/bundestagswahl/inhalt-1021204",
        "domain": "www.bundestag.de",
        "displayed_link": "https://www.bundestag.de › parlament › inhalt-1021204",
        "snippet": "Bundespräsident Frank-Walter Steinmeier hat am Freitag, 27. Dezember, den 20. Deutschen Bundestag gemäß Artikel 68 des Grundgesetzes aufgelöst.",
        "prerender": False
      },
      {
        "position": 5,
        "block_position": 8,
        "title": "Informationen zur Bundestagswahl 2025 - Bundesregierung.de",
        "link": "https://www.bundesregierung.de/breg-de/schwerpunkte-der-bundesregierung/bundestagswahl-2025",
        "domain": "www.bundesregierung.de",
        "displayed_link": "https://www.bundesregierung.de › breg-de › bundestag...",
        "snippet": "2025 findet die Bundestagswahl statt. Wie funktioniert die Wahl? Wie sicher ist die Wahl? Finden Sie hier zuverlässige Informationen.",
        "prerender": False
      }
    ],
    "knowledge_graph": {
      "id": "/g/11ry982h__",
      "title": "Bundestagswahl 2025",
      "website": "https://de.wikipedia.org/wiki/Bundestagswahl_2025",
      "source": {
        "name": "Wikipedia",
        "link": "https://de.wikipedia.org/wiki/Bundestagswahl_2025"
      },
      "description": "Die Wahl zum 21. Deutschen Bundestag wird als vorgezogene Neuwahl am 23. Februar 2025 stattfinden. Voraussetzung für diesen Termin war die gescheiterte Vertrauensfrage von Bundeskanzler Olaf Scholz vom 16. Dezember 2024, der diese und vorgezogene Neuwahlen nach dem Bruch der Ampelkoalition am 6.",
      "known_attributes": [
        {
          "attribute": "kc:/time/event:location2",
          "value": "Deutschland",
          "name": "kc:/time/event:location2",
          "link": "https://www.google.com/search?num=5&sca_esv=392315896b6345ed&hl=de&q=Deutschland&si=APYL9bu1Sl4M4TWndGcDs6ZL5WJXWNYEL_kgEEwAe0iMZIocdZmYNuT6v7hNnkScTa2BAlQzWnEAmBLARY68GtczKp5Hwe2Og8ag5APtl1pMGuncwPzxCmg0kE97Is4ne01yXb1pUvXN9J9i7splUAyl-vZCK_j3b6ZgRhUK2asvmLsvcq44oMnJ4v5htn_gRhHncjjyObA6&sa=X&ved=2ahUKEwi1t4C0rK2LAxV7JBAIHc3OH5cQmxMoAHoECBgQAg"
        }
      ],
      "block_position": 1
    },
    "top_stories": [
      {
        "title": "Die Bundestagswahl 2025 und die Kandidaten in Hagen",
        "link": "https://www.wp.de/lokales/hagen/article408235476/die-bundestagswahl-2025-und-die-kandidaten-in-hagen.html",
        "visible_initially": False,
        "source": "wp.de",
        "date": "vor 3 Stunden",
        "date_utc": "2025-02-05T17:14:43.717Z",
        "block_position": 2
      },
      {
        "title": "Bundestagswahl 2025: Wahlforum des Seniorenbeirates",
        "link": "https://meetingpoint-brandenburg.de/neuigkeiten/artikel/186688-bundestagswahl-2025-wahlforum-des-seniorenbeirates",
        "visible_initially": False,
        "source": "Meetingpoint Brandenburg",
        "date": "vor 1 Stunde",
        "block_position": 2
      },
      {
        "title": "Wahlkreis Hamburg-Mitte: Die Wahlergebnisse der Bundestagswahl 2025 im Überblick",
        "link": "https://www.augsburger-allgemeine.de/politik/ergebnisse-hamburg-mitte-bundestagswahl-2025-die-wahlergebnisse-im-ueberblick-104443560",
        "visible_initially": False,
        "source": "Augsburger Allgemeine",
        "date": "vor 45 Minuten",
        "date_utc": "2025-02-05T19:29:43.721Z",
        "block_position": 2
      },
      {
        "title": "Bundestagswahl 2025: Was die Parteien zu Europa sagen",
        "link": "https://www.ihre-vorsorge.de/soziales/nachrichten/bundestagswahl-2025-was-die-parteien-zu-europa-sagen",
        "visible_initially": False,
        "source": "Ihre-Vorsorge.de",
        "date": "vor 4 Stunden",
        "date_utc": "2025-02-05T16:14:43.723Z",
        "block_position": 2
      }
    ]
  }

# %%
class SERPResponseObject:
    def __init__(self, resp_obj: dict) -> None:
        self._resp = resp_obj
        self.obj = self._parse_response(resp_obj)

    def _parse_response(self, resp_obj: dict) -> dict:
        relevant_fields = {
            "organic_results": ["position", "title", "link", "snippet", "sitelinks"],
            "knowledge_graph": ["title", "website", "source", "description"],
            "top_stories": ["title", "link", "date"]
        }

        obj = {"organic_results": [], "knowledge_graph": {}, "top_stories": []}

        # Process organic results
        if "organic_results" in resp_obj:
            for result in resp_obj["organic_results"]:
                filtered_result = {key: result.get(key) for key in relevant_fields["organic_results"] if key in result}
                if filtered_result:
                    obj["organic_results"].append(filtered_result)

        # Process knowledge graph
        if "knowledge_graph" in resp_obj:
            for key in relevant_fields["knowledge_graph"]:
                if key in resp_obj["knowledge_graph"]:
                    obj["knowledge_graph"][key] = resp_obj["knowledge_graph"].get(key)

        # Process top stories
        if "top_stories" in resp_obj:
            for story in resp_obj["top_stories"]:
                filtered_story = {key: story.get(key) for key in relevant_fields["top_stories"] if key in story}
                if filtered_story:
                    obj["top_stories"].append(filtered_story)

        return obj


    def get_links(self) -> list[str]:
        organic_results_links = [
            result.get("link")
            for result in self.obj.get("organic_results", [])
            if result.get("link", None) is not None
        ]

        organic_results_side_links = [
            inline_link.get("link")
            for result in self.obj.get("organic_results", [])
            for inline_link in result.get("sitelinks", {})
                                     .get("inline", [])
            if inline_link.get("link", None) is not None
        ]

        knowledge_graph_link = self.obj.get("knowledge_graph", {}).get("website", None)
        knowledge_graph_links = [] if knowledge_graph_link is None else [knowledge_graph_link]

        top_stories_links = [
            story.get("link")
            for story in self.obj.get("top_stories", [])
            if story.get("link", None) is not None
        ]

        return organic_results_links \
               + organic_results_side_links \
               + knowledge_graph_links \
               + top_stories_links

# %%
obj = SERPResponseObject(result_dict)

# %%
obj.get_links()
# Out:
# ['https://www.bundeswahlleiterin.de/bundestagswahlen/2025.html',
#  'https://www.bundestag.de/wahl',
#  'https://de.wikipedia.org/wiki/Bundestagswahl_2025',
#  'https://www.bundestag.de/parlament/bundestagswahl/inhalt-1021204',
#  'https://www.bundesregierung.de/breg-de/schwerpunkte-der-bundesregierung/bundestagswahl-2025',
#  'https://www.bundeswahlleiterin.de/bundestagswahlen/2025/informationen-waehler.html',
#  'https://www.bundeswahlleiterin.de/bundestagswahlen/2025/termine.html',
#  'https://www.bundeswahlleiterin.de/bundestagswahlen/2025/wahlkreiseinteilung.html',
#  'https://www.bundeswahlleiterin.de/bundestagswahlen/2025/mitteilungen.html',
#  'https://de.wikipedia.org/wiki/Bundestagswahl_2025/Umfragen_und_Prognosen',
#  'https://de.wikipedia.org/wiki/B%C3%BCndnis_Sahra_Wagenknecht',
#  'https://de.wikipedia.org/wiki/Bruch_der_Ampelkoalition_in_Deutschland_2024',
#  'https://de.wikipedia.org/wiki/Bundestagswahl_2025',
# ...

# %%
from bs4 import BeautifulSoup
import re


deep_search_results = []
for link in obj.get_links():
    resp = requests.get(link)
    result_html = resp.text
    if resp.status_code != 200:
        result_html = "<p>no data<p>"

    soup = BeautifulSoup(result_html)

    result_html = re.sub(r'\n{3,}', '\n\n', soup.text)

    deep_search_results += [{
        "requested_link": link,
        "requested_link_html_content": result_html
    }]
    break

with open("./result.txt", "w") as f:
    f.write(str(deep_search_results))
