# %%
import os
import re
import json
import utils

from dotenv import load_dotenv


load_dotenv(".env")


from embedding import OpenAIEmbeddingModel  # noqa
from vectorindex import vector_search_index  # noqa

embedding_model = OpenAIEmbeddingModel(
    api_key=os.getenv("OPENAI_API_KEY"),
    embedding_endpoint=os.getenv("OPENAI_API_ENDPOINT_EMBEDDINGS")
)
os.getenv("OPENAI_API_ENDPOINT_EMBEDDINGS")
# Out:
# 'https://api.openai.com/v1/embeddings'

# %%
typecode = "WFHD0534"

search_term = """Die breite Palette applikationsspezifischer
Schallköpfe, samtliche in modernster
Breitbandtechnik, liefert erstklassige
Ergebnisse im klinischen Einsatz."""

max_result_count = 5

embeddings = embedding_model.embed(search_term)[0]

query = vector_search_index.generate_query_by_typecode(
    embeddings=embeddings,
    max_result_count=max_result_count,
    typeCode=typecode
)

results = vector_search_index.search(query)
for result in results:
    print(result)
# Out:
# {'id': '87543_pdf_page_5', 'typeCodes': ['WFHD0534'], 'documentName': '87543.pdf', 'documentPageNumber': 4, 'documentPageContent': '# document metadata start #\ndocument name: 87543.pdf\ndocument page number: 5\ntypecodes: wfhd0534\ndevice names: ultraschalldiagnosegerät\ntypes / models: voluson 530 d\ncategories / identifiers: wfhd\nmanufacturer: ge healthcare - global headquarters\nadditions: \n# DOCUMENT METADATA END #\n# DOCUMENT CONTENT START #\n## OCR RESULT\nea\nklinische\nvielseitigkeit\n\nes gibt wohl kaum eine diagnostische\nanwendung, die mit dem umfassenden\nvoluson®-system nicht zu bewéaltigen ist.\ndie breite palette applikationsspezifischer\nschallk6pfe, samtliche in modernster\nbreitbandtechnik, liefert erstklassige\nergebnisse im klinischen einsatz.\numfassende mess- und kalkulationsprogramme sowie vorbereitete protokollund reportseiten erleichtern die tagliche\nroutinearbeit.\n\ndas auf wunsch erhaltliche sonoviewTM\npaket ubernimmt die verwaltung und\narchivierung 
# ...

# %%
import pandas as pd

DATA_FOLDER_PATH = "../../../../resources/data/imt/files"
XL_FILES_PATH = "../../../../resources/data/imt/files.xlsx"
XL_DEVICE_TYPES_PATH = "../../../../resources/data/imt/imt_deviceTypes.xlsx"

df_files = pd.read_excel(XL_FILES_PATH)[["DokID", "Typcode", "DokName"]]
df_device_types = pd.read_excel(XL_DEVICE_TYPES_PATH)[["Typcode", "Gerät ID"]]

df = pd.merge(df_files, df_device_types, how="inner", on="Typcode")

# %%
df["DokName"].unique().shape[0]
# Out:
# 2918

# %%
import os

path = "./documents"


for root, dirs, files in os.walk(path):
    target = 2918
    current = len(files)
    diff = target - current
    s = f"Target:\t\t{target}\nCurrent:\t{current}\nDiff:\t\t{diff}"
    print(s)
# Out:
# Target:		2918
# Current:	2907
# Diff:		11

# %%
import os

path = "./etl/data/04-transform-final-embeddings"


for root, dirs, files in os.walk(path):
    target = 2906
    current = len(files)
    diff = target - current
    s = f"Target:\t\t{target}\nCurrent:\t{current}\nDiff:\t\t{diff}"
    print(s)
# Out:
# Target:		2906
# Current:	2878
# Diff:		28

# %%
s = "# document metadata start # document name: 290413-ga_wfhd0870.pdf document page number: 10 typecodes: wfhd0870, wfhd0972 device names: ultraschalldiagnosegerät types / models: acuson juniper, acuson juniper select categories / identifiers: wfhd manufacturer: siemens deutschland healthcare gmbh additions: udi: 04056869152059, model:11335791, udi: 04056869957357, model: 11653093 # document metadata end # # document content start # ## ocr result 1 einfihrung 1-2 gebrauchsanweisung ## pdf reader result 1 einführung 1 - 2 gebrauchsanweisung ## pdf tables # document content end #"
len(s.split("# document metadata end #"))
# Out:
# 2

# %%
import json
path = "./etl/data/04-transform-final-embeddings/87277.pdf.txt.embeddings.json"

with open(path, "r") as f:
    d = json.loads(f.read())

len(d["pages"][0]["documentPageContentEmbedding"])
# Out:
# 3072

# %%
token_str = """
###################### Page 153 of 828 ######################
# document metadata start #
document name: 261850-ga_wfhd0665_it.pdf
document page number: 153
typecodes: wfhd0665
device names: ultraschalldiagnosegerät
types / models: prosound alpha 7
categories / identifiers: wfhd
manufacturer: fujifilm corporation
additions: 
# DOCUMENT METADATA END #
# DOCUMENT CONTENT START #
## OCR RESULT
rev.

‘(pp 21g pue (ee|
z'1g ul ueaig sesnep uonduiexe yjoq sjoow jueidinbe eu) j! pepinoid oq jou pedu | pub iw uo lohewo;ul € slont

‘ssn a1jeydeo /eyeuoeu 40 elues9suen
40} papueyul jou atewassy hsongsnvul aue 40) ol. bulpueba1 papinoid aq you peau uonewo;u z slon|

‘apouy|

yeu) 40} si jo @n}ea wnwixew e4) buip)aia jou sll jo uonfeinulhos aue 404 pepinoid aq you peau uoneuo;u| | jlon|

abuey aiooiea xeidul,

bally ubis mo|4

jos mol4

bbeioay 10109

aisuaq sur 10}09

(gasjuy abuey ayoojan 40105

sn904 mo},

(zhi) }aieg aouanbary 1e\ddoq 40109,

700188 o6eun] 10)05

pasjui) __abuey ayooja, saiddoq

snoo¥ 18jddoq

gha) _paiag aouanbaiy 1e\ddoq

yai@g ebeu saiddoq

st

(%) bely ueos we

hoih

aysueg eu wa

ost

(wo) ebuey-wa

wa

sno04 wd

zhiil's || (zhin) pales aouenbaiy wa

uo

wonouny

001

(%) %vag

suomipuco
jonuco
buneiedo

(pp z'1g pue (ee
z'1g ul ueai6 sesnep uoydulexe yjog sjeew! juewdinbe eu) j! pepinoid eq jou peau || pue iw uo uoheuuo}ui € alon

sesn ajjeydeo jeyeuoeu 10 jelueosuen
4oj pepuejul jou atgwassv ysongsnvhl aue 40} 9}. gulpsebes papiaoid aq jou pasu uowewoju| zilon
“epow!

veu) 40} sil jo enjea winw kew oy) buipjaik jou sil jo uoreinuuo, aue 10) pepinoud oq jou peeu yohewuoju| | slon

8lz

zo/m) tw xew ye ty

(wio) “) -xew yep

(ed) 7 -xew yea]

@h) ad]

(9@8q) pr

very jo wid

me

(22)

os) xew ye z|

4z|

(27 c2 d] 40 win

d

ard]

uonewioju!
te)

ssojoweled
‘onsnose

‘anjea xepu wnwixe/]

ueds-uon
sul

apow-wa/a repo; buyeiedq

leqe] xepuy

snooy — lol alge

dsl9-lsn

opo jeonpsues |

li punoso.ig

om om yu on on on abuey ajoojen xedul
yu eu yu ea ea ea tt (%) bally ueds mo|4
we on we or or on teil mol
yu au yu et et et abeseay 10109
or wa or tal tal tal aysueq eur] 10/09
yu au yu et et eu |foospu) abuey a190/8/\ 10109
or wa or tal tal vl s904 moli
om om yu on on et || ghw) 1eies aouenbary 19\ddog 10109
yu eu yu ea ea ea wales ebew| 10j09
om om yu on on vu foespuo) __ ebuey ayoojen sejddog
yu eu yu ea ea ea sno0j 49\ddoq
wu aa wu eu eu eu (zhi) pejeg aouanbas4 sa\ddoq
yu au yu et et et wales ebeu| soiddoq
st - - = st st (%) ealy ueds ja] suonipucd
hoi - - : hoih | hoi aysueq eur wa] |oju0o
ol - - - oll oli (wo) ebuey-w9| buyjeredo
a : : : ld wd sno04 we
zhins - - - zhiws |zhinil’s | (zhin) yesles aouanbei4 m/a
i) : : : ho ho uonoun4
oor - : : 01 001 (%) %ag
ra tnxew ye t° 7]
- (wo) 1 xe yep
67 (ean) 4) xew ed uonewwoju!
jaul0
006¢ |] (2h) |
st0_ || (028d) pa
so - - - “so (wo) a
660 : : : 660 (wo) x| "7 yo wid
os - - - os ys || (hw) med)
- (wo) 2p
reo || (wo) os) kew ye z|
- (wo) 42] ssejowesed
- (ws) | onsnooe
- (wo) =z] peyeioossy
- (mu) (e297 (e28 dl yo ui
i - - u1 (mu) d
sz_ an) aid
ze0 - - - 970 al anjea xepuy whuixeyy
ueos [wore +l wos” y)
it | -uon weds-uon ues | iw lege] xepul
al sil
aiqe3 bupsodes yndyno aasnooy - 101 e1qel.
—opourg _—:epoyy buneiedo ——asio-isn jepow jeonpsued |,

le punosorg

17-25

## PDF READER RESULT
rev.
17-25
7(cid:302)dnuosorp
7(cid:302)dnuosorp
edom-m/b
:edom
gnitarepo
p576-tsu
:ledom
recudsnart
edom-b
:edom
gnitarepo
p576-tsu
:ledom
recudsnart
elbat
gnitroper
tuptuo
citsuoca
– 101
elbat
elbat
gnitroper
tuptuo
citsuoca
– 101
elbat
bit
sit
bit
sit
cit
-non
nacs-non
nacs
im
lebal xedni
cit
-non
nacs-non
nacs
im
lebal xedni
53.0
n 8a 2c .0s
2mc1
->trpaa2mc1
-<trpaa
32.0
2.1
eulav xedni
mumixam
nacs
2mc1>trpaa2mc1<trpaa
23.0
-
-
-
62.0
2.1
eulav xedni
mumixam
7.9
3.3
-
7.9
8.2
) )a wp mm ((
(cid:68),r pp
8.2
)apm(
(cid:68),rp
11
-
-
11
)wm(
p
9 70 9 5.5 . .0 0
57 6 7922 3 5... 4 . .00 0 0
- - - - - -
- - -
9 70 9 5.5 . .0 0
4 63 .. 50
)) z)) ) ) ) ) )w mm m m m m mhm cc c c c c cm(( ( ( ( ( (( (
])sz((cid:68),ati
x y,) (cid:68)s ,ipz tr( pi(cid:68) a.p x aa[ ) fmf b oo z m(tn fqap wi e ib bsm a ddz z z z fsd
re c eit tta esi u mc oo acs
7(cid:302)dnuosorp :ledom lebal xedni eulav xedni (cid:68),rp p fo nim sz pbz bzsretemarap (cid:68),ipi.xam taz )bz(qed fwaf x trpaa fo mid y dt rrp ipi.xam ta rp ipi .xam ta qed im.xam ta(cid:68),api %avd noitcnuf ycneuqerf w/b sucof w/b egnar-w/b ytisned enil w/b aera nacs w/b egami relppod ycneuqerf relppod sucof relppod yticolev relppod tceles egami roloc relppod roloc sucof wolf yticolev roloc ytisned enil roloc egareva roloc retlif wolf aera nacs wolf yticolev xelpirt eb ton deen noitamrofni eb ton deen noitamrofni cilahpec latanoen it dna im no noitamrofni .)dd
ro
recudsnart mumixam detaicossa citsuoca rehto noitamrofni gnitarepo lortnoc snoitidnoc lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: 
dhpe
cit 53.0 7.9 0.5 99.0 75.0 001 zhm5 1f 0.4 hgih 52 a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n 2.15
taht
fedhpe ni
rof rof nevig
bit -non nacs 82.0 3.3 72.0 52.0 9.4 63.0 75.0 42.0 001 zhm5 2f 0.71 hgih 52 a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n sit dednetni
edom-m/b fe fo sesualc
eulav
2mc1>trpaa2mc1<trpaa
ton
nacs-non - - - - - - - - - - - - - - a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n mumixam ylbmessa noitpmexe
:edom elbat sit - - - - - - - - - - - - a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n eht htob
gnitroper gnidleiy recudsnart steem
gnitarepo
nacs 32.0 7.9 0.5 99.0 75.0 001 ffo zhm5 1f 0.4 hgih 52 a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n ton tnempiuqe
tuptuo sit
citsuoca im 2.1 8.2 43.0 6.5 51.0 0483 9.2 872 001 ffo zhm17.5 2f 0.51 hgih 52 a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n fo noitalumrof yna rof eht
)apm( )wm( )wm( )mc( )mc( )mc( )mc( )mc( )zhm( )mc( )mc( )ces(cid:80)( )zh( )apm( )mc( )2mc/w( )%( )zhm( )mc( )%( )zhm( )ces/mc( )zhm( )ces/m( )%( cit gnidrager fi dedivorp
yna
p576-tsu – 101 tceles rof eb
elbat tceles dedivorp dedivorp ton
])sz((cid:68),ati,)sz((cid:68)p[ tceles tceles egnar ycneuqerf egnar egnar .sesu deen
7(cid:302)dnuosorp :ledom lebal xedni eulav xedni (cid:68),rp p fo nim sz pbz bzsretemarap (cid:68),ipi.xam taz )bz(qed fwaf x trpaa fo mid y dt rrp ipi.xam ta rp ipi .xam ta qed im.xam ta(cid:68),api %avd noitcnuf ycneuqerf w/b sucof w/b egnar-w/b ytisned enil w/b aera nacs w/b egami relppod ycneuqerf relppod sucof relppod yticolev relppod tceles egami roloc relppod roloc sucof wolf yticolev roloc ytisned enil roloc egareva roloc retlif wolf aera nacs wolf yticolev xelpirt eb ton deen noitamrofni eb ton deen noitamrofni cilahpec latanoen it dna im no noitamrofni .)dd
ro
recudsnart mumixam detaicossa citsuoca rehto noitamrofni gnitarepo lortnoc snoitidnoc lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: cit 23.0 11 0.5 99.0 75.0 001 ffo zhm5 1f 0.11 hgih 52 a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n 2.15
taht
ni
rof rof nevig
bit -non nacs - - - - - - - - - - - - - - - a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n sit dednetni
edom-b fo sesualc
eulav
2mc1>trpaa2mc1<trpaa
ton
nacs-non - - - - - - - - - - - - - - a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n mumixam ylbmessa noitpmexe
:edom elbat sit - - - - - - - - - - - - a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n eht htob
gnitroper gnidleiy recudsnart steem
gnitarepo
nacs 62.0 11 0.5 99.0 75.0 001 ffo zhm5 1f 0.11 hgih 52 a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n ton tnempiuqe
tuptuo sit
citsuoca im 2.1 8.2 43.0 6.5 51.0 0093 9.2 872 001 ffo zhm17.5 2f 0.71 hgih 52 a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n a/n fo noitalumrof yna rof eht
)apm( )wm( )wm( )mc( )mc( )mc( )mc( )mc( )zhm( )mc( )mc( )ces(cid:80)( )zh( )apm( )mc( )2mc/w( )%( )zhm( )mc( )%( )zhm( )ces/mc( )zhm( )ces/m( )%( cit gnidrager fi dedivorp
yna
p576-tsu – 101 tceles rof eb
elbat tceles dedivorp dedivorp ton
])sz((cid:68),ati,)sz((cid:68)p[ tceles tceles egnar ycneuqerf egnar egnar .sesu deen
7(cid:302)dnuosorp :ledom lebal xedni eulav xedni (cid:68),rp p fo nim sz pbz bzsretemarap (cid:68),ipi.xam taz )bz(qed fwaf x trpaa fo mid y dt rrp ipi.xam ta rp ipi .xam ta qed im.xam ta(cid:68),api %avd noitcnuf ycneuqerf w/b sucof w/b egnar-w/b ytisned enil w/b aera nacs w/b egami relppod ycneuqerf relppod sucof relppod yticolev relppod tceles egami roloc relppod roloc sucof wolf yticolev roloc ytisned enil roloc egareva roloc retlif wolf aera nacs wolf yticolev xelpirt eb ton deen noitamrofni eb ton deen noitamrofni cilahpec latanoen it dna im no noitamrofni .)dd
ro
recudsnart mumixam detaicossa citsuoca rehto noitamrofni gnitarepo lortnoc snoitidnoc lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa

table 1 content:
cit: bit, none: -non nacs, none: none, 53.0: 82.0, : , 7.9: 3.3, : , : , : , : 72.0, : , : 52.0, 0.5: 9.4, 99.0: 63.0, 75.0: 75.0, : , : , : , : 42.0, : , 001: 001, dhpe
fe: dhpe
fe, zhm5: zhm5, 1f: 2f, 0.4: 0.71, hgih: hgih, 52: 52, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: sit, none: nacs-non, none: 2mc1>trpaa, 53.0: -, : , 7.9: , : -, : -, : -, : , : , : , 0.5: -, 99.0: -, 75.0: -, : , : , : , : , : , 001: -, dhpe
fe: -, zhm5: -, 1f: -, 0.4: -, hgih: -, 52: -, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: none, none: 2mc1<trpaa, 53.0: -, : , 7.9: -, : , : , : , : , : , : , 0.5: -, 99.0: -, 75.0: -, : , : , : , : , : , 001: -, dhpe
fe: -, zhm5: -, 1f: -, 0.4: -, hgih: -, 52: -, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: nacs, none: none, 53.0: 32.0, : , 7.9: 7.9, : , : , : , : , : , : , 0.5: 0.5, 99.0: 99.0, 75.0: 75.0, : , : , : , : , : , 001: 001, dhpe
fe: ffo, zhm5: zhm5, 1f: 1f, 0.4: 0.4, hgih: hgih, 52: 52, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: im, none: none, none: none, 53.0: 2.1, : 8.2, 7.9: , : , : , : , : , : 43.0, : , 0.5: 6.5, 99.0: , 75.0: , : 51.0, : 0483, : 9.2, : , : 872, 001: 001, dhpe
fe: ffo, zhm5: zhm17.5, 1f: 2f, 0.4: 0.51, hgih: hgih, 52: 52, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: lebal
xedni, none: none, none: none, 53.0: eulav
xedni
mumixam, : )apm(
(cid:68),rp, 7.9: )wm(
p, : )wm(
])sz((cid:68),ati,)sz((cid:68)p[
fo
nim, : )mc(
sz, : )mc(
pbz, : )mc(
bz, : )mc(
(cid:68),ipi.xam
taz, : )mc(
)bz(qed, 0.5: )zhm(
fwaf, 99.0: )mc(
x, 75.0: )mc(
y, : )ces(cid:80)(
dt, : )zh(
rrp, : )apm(
ipi.xam
ta
rp, : )mc(
ipi
.xam
ta
qed, : )2mc/w(
im.xam
ta(cid:68),api, 001: )%(
# %avd, dhpe
fe: noitcnuf, zhm5: )zhm(
tceles
ycneuqerf
w/b, 1f: sucof
w/b, 0.4: )mc(
egnar-w/b, hgih: ytisned
enil
w/b, 52: )%(
aera
nacs
w/b, a/n: tceles
egami
relppod, a/n: )zhm(
tceles
ycneuqerf
relppod, a/n: sucof
relppod, a/n: )ces/mc(
egnar
yticolev
relppod, a/n: tceles
egami
roloc, a/n: )zhm(
tceles
ycneuqerf
relppod
roloc, a/n: sucof
wolf, a/n: )ces/m(
egnar
yticolev
roloc, a/n: ytisned
enil
roloc, a/n: egareva
roloc, a/n: retlif
wolf, a/n: )%(
aera
nacs
wolf, a/n: egnar
yticolev
xelpirt, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: none, none: none, 53.0: none, : none, 7.9: none, : none, : none, : none, : none, : none, : none, 0.5: none, 99.0: trpaa
fo
mid, 75.0: none, : none, : none, : none, : none, : none, 001: none, dhpe
fe: none, zhm5: none, 1f: none, 0.4: none, hgih: none, 52: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: none, none: none, 53.0: none, : detaicossa sretemarap
citsuoca, 7.9: none, : none, : none, : none, : none, : none, : none, 0.5: none, 99.0: none, 75.0: none, : noitamrofni
rehto, : none, : none, : none, : none, 001: gnitarepo snoitidnoc
lortnoc, dhpe
fe: none, zhm5: none, 1f: none, 0.4: none, hgih: none, 52: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none

table 2 content:
cit: bit, none: -non nacs, none: none, 23.0: -, : , 11: -, : , : , : , : -, : , : -, 0.5: -, 99.0: -, 75.0: -, : , : , : , : -, : , 001: -, ffo: -, zhm5: -, 1f: -, 0.11: -, hgih: -, 52: -, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: sit, none: nacs-non, none: 2mc1>
a, 23.0: -
trpa, : , 11: , : -, : -, : -, : , : , : , 0.5: -, 99.0: -, 75.0: -, : , : , : , : , : , 001: -, ffo: -, zhm5: -, 1f: -, 0.11: -, hgih: -, 52: -, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: none, none: 2mc1<
a, 23.0: -
trpa, : , 11: -, : , : , : , : , : , : , 0.5: -, 99.0: -, 75.0: -, : , : , : , : , : , 001: -, ffo: -, zhm5: -, 1f: -, 0.11: -, hgih: -, 52: -, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: nacs, none: none, 23.0: 62.0, : , 11: 11, : , : , : , : , : , : , 0.5: 0.5, 99.0: 99.0, 75.0: 75.0, : , : , : , : , : , 001: 001, ffo: ffo, zhm5: zhm5, 1f: 1f, 0.11: 0.11, hgih: hgih, 52: 52, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: im, none: none, none: none, 23.0: 2.1, : 8.2, 11: , : , : , : , : , : 43.0, : , 0.5: 6.5, 99.0: , 75.0: , : 51.0, : 0093, : 9.2, : , : 872, 001: 001, ffo: ffo, zhm5: zhm17.5, 1f: 2f, 0.11: 0.71, hgih: hgih, 52: 52, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, a/n: a/n, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: lebal
xedni, none: none, none: none, 23.0: eulav
xedni
mumixam, : )apm(
(cid:68),rp, 11: )wm(
p, : )wm(
])sz((cid:68),ati,)sz((cid:68)p[
fo
nim, : )mc(
sz, : )mc(
pbz, : )mc(
bz, : )mc(
(cid:68),ipi.xam
taz, : )mc(
)bz(qed, 0.5: )zhm(
fwaf, 99.0: )mc(
x, 75.0: )mc(
y, : )ces(cid:80)(
dt, : )zh(
rrp, : )apm(
ipi.xam
ta
rp, : )mc(
ipi
.xam
ta
qed, : )2mc/w(
im.xam
ta(cid:68),api, 001: )%(
# %avd, ffo: noitcnuf, zhm5: )zhm(
tceles
ycneuqerf
w/b, 1f: sucof
w/b, 0.11: )mc(
egnar-w/b, hgih: ytisned
enil
w/b, 52: )%(
aera
nacs
w/b, a/n: tceles
egami
relppod, a/n: )zhm(
tceles
ycneuqerf
relppod, a/n: sucof
relppod, a/n: )ces/mc(
egnar
yticolev
relppod, a/n: tceles
egami
roloc, a/n: )zhm(
tceles
ycneuqerf
relppod
roloc, a/n: sucof
wolf, a/n: )ces/m(
egnar
yticolev
roloc, a/n: ytisned
enil
roloc, a/n: egareva
roloc, a/n: retlif
wolf, a/n: )%(
aera
nacs
wolf, a/n: egnar
yticolev
xelpirt, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: none, none: none, 23.0: none, : none, 11: none, : none, : none, : none, : none, : none, : none, 0.5: none, 99.0: trpaa
fo
mid, 75.0: none, : none, : none, : none, : none, : none, 001: none, ffo: none, zhm5: none, 1f: none, 0.11: none, hgih: none, 52: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
cit: none, none: none, none: none, 23.0: none, : detaicossa sretemarap
citsuoca, 11: none, : none, : none, : none, : none, : none, : none, 0.5: none, 99.0: none, 75.0: none, : noitamrofni
rehto, : none, : none, : none, : none, 001: gnitarepo snoitidnoc
lortnoc, ffo: none, zhm5: none, 1f: none, 0.11: none, hgih: none, 52: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, a/n: none, 2.15
taht
ni
rof rof nevig
sit dednetni
fo sesualc
eulav
ton
mumixam ylbmessa noitpmexe
eht htob
gnidleiy recudsnart steem
ton tnempiuqe
sit
fo yna
noitalumrof rof eht
cit fi dedivorp
gnidrager
yna
rof eb
dedivorp dedivorp ton
deen
.sesu
eb eb it
ton ton cilahpec dna
deen deen im
latanoen no
noitamrofni noitamrofni noitamrofni
.)dd
ro
lainarcsnart 2.15
1 2 3 dna
eton .edom eton eton
)aa: none
# DOCUMENT CONTENT END #
"""

# %%
import tiktoken

def count_tokens(text, model="text-embedding-3-small"):
    encoding = tiktoken.encoding_for_model(model)
    return len(encoding.encode(text))

count_tokens(token_str)
# Out:
# 13575

# %%
def trim_to_token_limit(text, max_tokens=8000, model="text-embedding-3-small"):
    encoding = tiktoken.encoding_for_model(model)
    tokens = encoding.encode(text)

    if len(tokens) <= max_tokens:
        return text  # Already within limit

    # Decode only the first `max_tokens` tokens back to text
    trimmed_text = encoding.decode(tokens[:max_tokens])
    
    return trimmed_text

token_str_trimmed = trim_to_token_limit(token_str, 8000)
count_tokens(token_str_trimmed)
# Out:
# 8000
